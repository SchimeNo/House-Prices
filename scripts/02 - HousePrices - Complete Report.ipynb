# %%
# Python Project Template

# 4. Evaluate Algorithms
# a) Split-out validation dataset
# b) Test options and evaluation metric
# c) Spot Check Algorithms
# d) Compare Algorithms

# 5. Improve Accuracy
# a) Algorithm Tuning
# b) Ensembles

# 6. Finalize Model
# a) Predictions on validation dataset
# b) Create standalone model on entire training dataset
# c) Save model for later use

# %%
#Load libraries

#!pip install pyforest
from pyforest import *
import tsfresh

# %%
#LOAD DATA
df_train=pd.read_csv('C:/Users/Sergi Ch/Downloads/UBIQUM/@a SAMPLE PROJECTS/House Prices/House Prices/datasets/train.csv')
df_train_aux=df_train

# %% [markdown]
# ### PREPARING THE DATA ###

# %%
#Data Cleaning

#missing data
total = df_train.isnull().sum().sort_values(ascending=False)
percent = (df_train.isnull().sum()/df_train.isnull().count()).sort_values(ascending=False)
missing_data = pd.concat([total, percent], axis=1, keys=['Total', 'Percent'])
missing_data.head(20)
#dealing with missing data
df_train = df_train.drop((missing_data[missing_data['Total'] > 1]).index,1)
df_train = df_train.drop(df_train.loc[df_train['Electrical'].isnull()].index)
df_train.isnull().sum().max() #just checking that there's no missing data missing...
# Out:
# 0

# %%
#FEATURE SELECTION with tsfresh (only numeric)

Y=df_train['SalePrice']
X=df_train.loc[:, df_train.columns != 'SalePrice']

X=X.select_dtypes(exclude=['object']) #exclude object variables


features=tsfresh.feature_selection.relevance.calculate_relevance_table(X, Y, ml_task='regression', n_jobs=2, chunksize=None, test_for_binary_target_binary_feature='fisher', test_for_binary_target_real_feature='mann', test_for_real_target_binary_feature='mann', test_for_real_target_real_feature='kendall', fdr_level=0.05, hypotheses_independent=False)
features
# Out:
#                      feature  type        p_value  relevant
# feature
# OverallQual      OverallQual  real  6.813626e-268      True
# GrLivArea          GrLivArea  real  7.469035e-212      True
# GarageCars        GarageCars  real  6.132723e-176      True
# GarageArea        GarageArea  real  7.020103e-163      True
# YearBuilt          YearBuilt  real  2.380142e-157      True
# TotalBsmtSF      TotalBsmtSF  real  1.928089e-136      True
# FullBath            FullBath  real  5.309088e-133      True
# 1stFlrSF            1stFlrSF  real  2.041804e-122      True
# YearRemodAdd    YearRemodAdd  real  3.328563e-119      True
# TotRmsAbvGrd    TotRmsAbvGrd  real  1.676046e-103      True
# Fireplaces        Fireplaces  real   3.763727e-88      True
# OpenPorchSF      OpenPorchSF  real   3.143603e-78      True
# LotArea              LotArea  real   5.402931e-72      True
# WoodDeckSF        WoodDeckSF  real   1.466043e-42      True
# HalfBath            HalfBath  real   4.978761e-39      True
# BsmtFinSF1        BsmtFinSF1  real   4.148603e-34      True
# 2ndFlrSF            2ndFlrSF  real   1.191813e-33      True
# BedroomAbvGr    BedroomAbvGr  real   3.213266e-20      True
# BsmtFullBath    BsmtFullBath  real   7.609439e-18      True
# EnclosedPorch  EnclosedPorch  real   8.550935e-17      True
# BsmtUnfSF          BsmtUnfSF  real   3.785898e-13      True
# KitchenAbvGr    KitchenAbvGr  real   3.067306e-10      True
# OverallCond      OverallCond  real   1.967946e-07      True
# ScreenPorch      ScreenPorch  real   1.217395e-04      True
# MoSold                MoSold  real   7.136329e-03      True
# LowQualFinSF    LowQualFinSF  real   9.494991e-03     False
# 3SsnPorch          3SsnPorch  real   1.220178e-02     False
# MiscVal              MiscVal  real   1.657702e-02     False
# PoolArea            PoolArea  real   2.546969e-02     False
# BsmtFinSF2        BsmtFinSF2  real   1.405272e-01     False
# YrSold                YrSold  real   2.566013e-01     False
# Id                        Id  real   4.893207e-01     False
# BsmtHalfBath    BsmtHalfBath  real   6.424261e-01     False
# MSSubClass        MSSubClass  real   8.378430e-01     False

# %%
#Feature Selection

features=features[features['relevant']==True]
cols=[features['feature']]
cols
#cols = ['OverallQual', 'GrLivArea', 'GarageCars', 'TotalBsmtSF', 'FullBath', 'YearBuilt']
#X=df_train[cols]
# Out:
# [feature
#  OverallQual        OverallQual
#  GrLivArea            GrLivArea
#  GarageCars          GarageCars
#  GarageArea          GarageArea
#  YearBuilt            YearBuilt
#  TotalBsmtSF        TotalBsmtSF
#  FullBath              FullBath
#  1stFlrSF              1stFlrSF
#  YearRemodAdd      YearRemodAdd
#  TotRmsAbvGrd      TotRmsAbvGrd
#  Fireplaces          Fireplaces
#  OpenPorchSF        OpenPorchSF
#  LotArea                LotArea
#  WoodDeckSF          WoodDeckSF
#  HalfBath              HalfBath
#  BsmtFinSF1          BsmtFinSF1
#  2ndFlrSF              2ndFlrSF
#  BedroomAbvGr      BedroomAbvGr
#  BsmtFullBath      BsmtFullBath
#  EnclosedPorch    EnclosedPorch
#  BsmtUnfSF            BsmtUnfSF
#  KitchenAbvGr      KitchenAbvGr
#  OverallCond        OverallCond
#  ScreenPorch        ScreenPorch
#  MoSold                  MoSold
#  Name: feature, dtype: object]

# %%
#FEATURE SELECTION
tsfresh.feature_selection.relevance.calculate_relevance_table(X, Y, ml_task='regression', n_jobs=2, chunksize=None, test_for_binary_target_binary_feature='fisher', test_for_binary_target_real_feature='mann', test_for_real_target_binary_feature='mann', test_for_real_target_real_feature='kendall', fdr_level=0.05, hypotheses_independent=False)
# Out:
# ---------------------------------------------------------------------------
# RemoteTraceback                           Traceback (most recent call last)
# RemoteTraceback:
# """
# Traceback (most recent call last):
#   File "C:\Anaconda3\lib\multiprocessing\pool.py", line 121, in worker
#     result = (True, func(*args, **kwds))
#   File "C:\Anaconda3\lib\multiprocessing\pool.py", line 44, in mapstar
#     return list(map(*args))
#   File "C:\Anaconda3\lib\site-packages\tsfresh\feature_selection\significance_tests.py", line 183, in target_real_feature_real_test
#     _check_for_nans(x, y)
#   File "C:\Anaconda3\lib\site-packages\tsfresh\feature_selection\significance_tests.py", line 259, in _check_for_nans
#     if np.isnan(x.values).any():
# TypeError: ufunc 'isnan' not supported for the input types, and the inputs could not be safely coerced to any supported types according to the casting rule ''safe''
# """
#
# The above exception was the direct cause of the following exception:
#
# TypeError                                 Traceback (most recent call last)
# <ipython-input-17-66923f773d31> in <module>
#       1 #FEATURE SELECTION
# ----> 2 tsfresh.feature_selection.relevance.calculate_relevance_table(X, Y, ml_task='regression', n_jobs=2, chunksize=None, test_for_binary_target_binary_feature='fisher', test_for_binary_target_real_feature='mann', test_for_real_target_binary_feature='mann', test_for_real_target_real_feature='kendall', fdr_level=0.05, hypotheses_independent=False)
#
# C:\Anaconda3\lib\site-packages\tsfresh\feature_selection\relevance.py in calculate_relevance_table(X, y, ml_task, n_jobs, chunksize, test_for_binary_target_binary_feature, test_for_binary_target_real_feature, test_for_real_target_binary_feature, test_for_real_target_real_feature, fdr_level, hypotheses_independent)
#     175         relevance_table = _calculate_relevance_table_for_implicit_target(
#     176             table_real, table_binary, X, _test_real_feature, _test_binary_feature, hypotheses_independent, fdr_level,
# --> 177             map_function
#     178         )
#     179
#
# C:\Anaconda3\lib\site-packages\tsfresh\feature_selection\relevance.py in _calculate_relevance_table_for_implicit_target(table_real, table_binary, X, test_real_feature, test_binary_feature, hypotheses_independent, fdr_level, map_function)
#     196                                                    hypotheses_independent, fdr_level, map_function):
#     197     table_real['p_value'] = pd.Series(
# --> 198         map_function(test_real_feature, [X[feature] for feature in table_real.index]),
#     199         index=table_real.index
#     200     )
#
# C:\Anaconda3\lib\multiprocessing\pool.py in map(self, func, iterable, chunksize)
#     266         in a list that is returned.
#     267         '''
# --> 268         return self._map_async(func, iterable, mapstar, chunksize).get()
#     269
#     270     def starmap(self, func, iterable, chunksize=None):
#
# C:\Anaconda3\lib\multiprocessing\pool.py in get(self, timeout)
#     655             return self._value
#     656         else:
# --> 657             raise self._value
#     658
#     659     def _set(self, i, obj):
#
# TypeError: ufunc 'isnan' not supported for the input types, and the inputs could not be safely coerced to any supported types according to the casting rule ''safe''

# %%
#COLUMNS THAT WILL BE USED
#
df
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-9-2d1ef5e55129> in <module>
#       1 #COLUMNS THAT WILL BE USED
#       2 #
# ----> 3 df
#
# NameError: name 'df' is not defined
